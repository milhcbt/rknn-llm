// %%
#include <iostream>

std::cout << __cplusplus << std::endl;
// Out:
// 202302

// %%
#if __has_include("/home/milh/micromamba/envs/xeus-cpp/include/torch/csrc/api/include/torch/autograd.h")
const char* result = "ABS_FOUND";
#else
const char* result = "ABS_NOT_FOUND";
#endif

std::cout << result << std::endl;
// Out:
// ABS_FOUND

// %%
#if __has_include(<torch/autograd.h>)
const char* result01 = "FOUND";
#else
const char* result01 = "NOT_FOUND";
#endif

std::cout << result01 << std::endl;
// Out:
// NOT_FOUND

// %%
#include <torch/csrc/api/include/torch/version.h>
#include <iostream>

std::cout << TORCH_VERSION << std::endl;
// Out:
// 2.10.0

// %%
#include <torch/types.h>

std::cout << "OK\n";
// Out:
// In file included from <<< inputs >>>:1:
// input_line_6:1:10: fatal error: 'torch/types.h' file not found
//     1 | #include <torch/types.h>
//       |          ^~~~~~~~~~~~~~~
// Failed to parse via ::process:Parsing failed.
// Error: Compilation error! In file included from <<< inputs >>>:1:
// input_line_6:1:10: fatal error: 'torch/types.h' file not found
//     1 | #include <torch/types.h>
//       |          ^~~~~~~~~~~~~~~
// Failed to parse via ::process:Parsing failed.

// %%
import torch
